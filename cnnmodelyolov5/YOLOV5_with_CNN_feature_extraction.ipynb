# %% [markdown]
# <a href="https://colab.research.google.com/github/Tabs2206/Meteor-Detection/blob/main/cnnmodelyolov5/YOLOV5_with_CNN_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch  # Import PyTorch
import torch.nn as nn  # Import the neural network module
import torchvision.models as models  # Import the models module from torchvision

# Load a pre-trained ResNet model
model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

# Remove the final classification layer
feature_extractor = torch.nn.Sequential(*(list(model.children())[:-1]))

# Test with a random image of size 860x538
input_data = torch.randn(1, 3, 538, 860)  # (batch_size, channels, height, width)
features = feature_extractor(input_data)
print(features.shape)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 209MB/s]
# torch.Size([1, 512, 1, 1])

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt  # Install requirements
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16867, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 16867 (delta 14), reused 28 (delta 4), pack-reused 16825 (from 1)
# Receiving objects: 100% (16867/16867), 15.60 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (11563/11563), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 112.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.0/869.0 kB 466.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.5 MB/s eta 0:00:00

# %% [markdown]
# ## Changes in Architecture
# #### In order to add feature extraction we need to perform some changes in YOLOV5 Architecture
#
# We need to change the YAML file contant to the below in order to perform feature extraction.
#
#
#
#
# ```
# # Ultralytics YOLOv5 🚀, AGPL-3.0 license
#
# # Parameters
# nc: 80 # number of classes
# depth_multiple: 0.33 # model depth multiple
# width_multiple: 0.50 # layer channel multiple
# anchors:
#   - [10, 13, 16, 30, 33, 23] # P3/8
#   - [30, 61, 62, 45, 59, 119] # P4/16
#   - [116, 90, 156, 198, 373, 326] # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [
#     [-1, 1, Conv, [64, 6, 2, 2]],  # Example backbone conv layers
#     [-1, 1, Conv, [256, 3, 2]],
#     [-1, 3, C3, [256]],
#     [-1, 1, Conv, [256, 3, 2]],  # Example P3/8
#     [-1, 6, C3, [256]],
#     [-1, 1, Conv, [512, 3, 2]],  # Example P4/16
#     [-1, 9, C3, [512]],
#     [-1, 1, Conv, [1024, 3, 2]],  # Example P5/32
#     [-1, 3, C3, [1024]],
#     [-1, 1, SPPF, [1024, 5]],     # Example SPPF
#   ]
#
# head: [
#     # x1 and x2 processing and concatenation
#     [-1, 1, Conv, [256, 1, 1]],  # x1 Conv: 256 channels
#     [-1, 1, Conv, [192, 1, 1]],  # x2 Conv: 192 channels
#
#     # Concatenate
#     [[-1, 6], 1, Concat, [1]],   # Concatenate x1 and x2 -> 448 channels
#
#     # Post-concat Conv to match the next layer's requirements
#     [-1, 1, Conv, [512, 1, 1]],  # Adjust to 512 channels
#
#     # Continue with upsampling or other operations
#     [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#     [[-1, 4], 1, Concat, [1]],   # Further concatenation
#     [-1, 3, C3, [256, 128, 1, False]],  # Processing continues
# ]
#
#
#
# ```
# Once the changes is done the the yolov5s.yaml file and run the below code. Make sure the path of the file is correctly set.

# %%
import torch
import torch.nn as nn
from torchvision import models
from yolov5.models.yolo import Model

# Custom CNN model definition
class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN, self).__init__()
        # Load a pre-trained ResNet model
        self.resnet = models.resnet50(pretrained=True)
        # Use all layers except the last fully connected layer
        self.feature_extractor = nn.Sequential(*list(self.resnet.children())[:-2])
        # Add a 1x1 convolution to adjust the number of output channels to 128
        self.channel_adjust = nn.Conv2d(2048, 256, kernel_size=1)

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.channel_adjust(x)  # Adjust channels to match YOLOv5 expectations
        return x

# Define a new YOLOv5 model with a custom backbone
class YOLOv5CustomBackbone(Model):
    def __init__(self, cfg='/content/yolov5/models/yolov5s.yaml', ch=256, nc=1):
        super().__init__(cfg, ch, nc)
        # Replace the default backbone with your custom CNN
        self.model[0] = CustomCNN()  # Assuming the first layer is the backbone
        # Initialize 'self.d' for the 'Concat' module in YOLOv5
        self.model[-1].d = -1 # Set the concatenation dimension to the last dimension

    def forward(self, x):
        x1 = self.model[6](x)
        x2 = self.model[-1](x)
        print("Shape of x1 (layer 6 output):", x1.shape)
        print("Shape of x2 (current layer output):", x2.shape)
        x = torch.cat([x1, x2], dim=1)
        return x
# Instantiate the model
model = YOLOv5CustomBackbone()
# Out:
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1    294976  models.common.Conv                      [256, 32, 6, 2, 2]
#   1                -1  1     37120  models.common.Conv                      [32, 128, 3, 2]
#   2                -1  1     74496  models.common.C3                        [128, 128, 1]
#   3                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  11                -1  1     12480  models.common.Conv                      [128, 96, 1, 1]
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90624  models.common.Conv                      [352, 256, 1, 1]
#  14                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  15           [-1, 4]  1         0  models.common.Concat                    [1]
#  16                -1  1       256  models.common.C3                        [384, 128, 1, 128, 1, False]
# YOLOv5s summary: 149 layers, 4780032 parameters, 4780032 gradients
#
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 213MB/s]

# %% [markdown]
# # Include a YAML
#
# For training the model in our own classifiation we need to add a new YAML file containing the below details.
#
#
#
# ```
# train: /content/drive/MyDrive/class_meteor/images/train # path to training images
# val: /content/drive/MyDrive/class_meteor/images/val  # path to validation images
# test: /content/drive/MyDrive/class_meteor/images/test  # path to test images (optional)
#
#
# nc: 1  # number of classes
# names: ['meteor']  # class names
# ```
#
# This will contain the path of the labelled data set for training, validation and test and the class i.e, meteor in our case.
#
# Drag and drop the file in the file path "/content/yolov5/data"
#
# In the below code we have utilse is under --data to get the training data for training our(train.py)

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 200 --data /content/yolov5/data/coco128_meteor.yaml --weights yolov5s.pt --name meteor
# Out:
# 2024-08-18 22:47:31.639647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-18 22:47:31.659799: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-18 22:47:31.665714: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/coco128_meteor.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=meteor, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 77.7MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 348MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.13). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/class_meteor/labels/train.cache... 499 images, 1 backgrounds, 0 corrupt: 100% 500/500 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/class_meteor/labels/val.cache... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<?, ?it/s]
#
# AutoAnchor: 3.61 anchors/target, 0.984 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/meteor/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/meteor
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/199      3.66G     0.1212    0.06422          0         73        640: 100% 32/32 [00:33<00:00,  1.06s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:21<00:00,  5.33s/it]
#                    all        100       1085     0.0058       0.16    0.00925    0.00239
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/199       3.9G     0.1033    0.06787          0         97        640: 100% 32/32 [00:06<00:00,  4.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.77it/s]
#                    all        100       1085      0.119      0.185     0.0677     0.0139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/199       3.9G    0.09687    0.05974          0        100        640: 100% 32/32 [00:06<00:00,  4.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.04it/s]
#                    all        100       1085     0.0565       0.12     0.0308    0.00728
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/199       3.9G    0.09186    0.05913          0         80        640: 100% 32/32 [00:06<00:00,  4.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.47it/s]
#                    all        100       1085      0.392      0.428      0.298     0.0625
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/199       3.9G    0.08131    0.06413          0         72        640: 100% 32/32 [00:06<00:00,  4.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.20it/s]
#                    all        100       1085      0.297      0.407      0.259     0.0606
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/199       3.9G    0.07593    0.06656          0         61        640: 100% 32/32 [00:06<00:00,  4.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.57it/s]
#                    all        100       1085      0.467      0.517      0.397     0.0912
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/199       3.9G    0.07141    0.06677          0        121        640: 100% 32/32 [00:06<00:00,  4.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.41it/s]
#                    all        100       1085      0.272      0.506      0.248     0.0564
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/199       3.9G    0.07196    0.06715          0         95        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.54it/s]
#                    all        100       1085      0.426      0.515      0.382     0.0916
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/199       3.9G    0.07142    0.06661          0         85        640: 100% 32/32 [00:06<00:00,  4.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.72it/s]
#                    all        100       1085        0.5       0.59      0.493      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/199       3.9G    0.06661    0.06827          0        113        640: 100% 32/32 [00:06<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.57it/s]
#                    all        100       1085      0.647      0.641      0.627      0.177
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/199       3.9G    0.06728    0.06637          0         64        640: 100% 32/32 [00:07<00:00,  4.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.71it/s]
#                    all        100       1085      0.675      0.663      0.665       0.18
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/199       3.9G    0.06497    0.06756          0         92        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.55it/s]
#                    all        100       1085      0.677       0.65      0.675      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/199       3.9G    0.06454    0.06798          0         91        640: 100% 32/32 [00:06<00:00,  4.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.66it/s]
#                    all        100       1085      0.684      0.731      0.706      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/199       3.9G    0.06572    0.06627          0         81        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.54it/s]
#                    all        100       1085      0.671      0.651      0.644      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/199       3.9G    0.06642    0.06636          0         79        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.80it/s]
#                    all        100       1085      0.703      0.717      0.715      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/199       3.9G    0.06433    0.06229          0         24        640: 100% 32/32 [00:06<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.49it/s]
#                    all        100       1085      0.732      0.738      0.725      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/199       3.9G    0.06361    0.06644          0         53        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.75it/s]
#                    all        100       1085      0.665      0.696      0.667      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/199       3.9G    0.06085    0.06641          0         63        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.32it/s]
#                    all        100       1085      0.682      0.703      0.706      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/199       3.9G    0.06248    0.06391          0         59        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.75it/s]
#                    all        100       1085      0.742      0.726      0.714      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/199       3.9G    0.06139    0.06124          0         55        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.18it/s]
#                    all        100       1085      0.653      0.676      0.659      0.181
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/199       3.9G    0.06118    0.06447          0         68        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.69it/s]
#                    all        100       1085      0.656      0.658       0.66      0.179
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/199       3.9G    0.06099    0.06375          0         61        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.48it/s]
#                    all        100       1085       0.69      0.714      0.685      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/199       3.9G    0.06035    0.06808          0         96        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.75it/s]
#                    all        100       1085      0.711      0.708      0.713      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/199       3.9G    0.06158    0.06463          0         54        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.42it/s]
#                    all        100       1085      0.689       0.69       0.69      0.197
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/199       3.9G    0.06185    0.06605          0         83        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.69it/s]
#                    all        100       1085      0.602      0.679      0.591      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/199       3.9G    0.06007    0.06346          0         46        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.42it/s]
#                    all        100       1085       0.68      0.747      0.715      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/199       3.9G    0.06176    0.06484          0         78        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.64it/s]
#                    all        100       1085      0.682      0.688      0.666      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/199       3.9G    0.05939     0.0653          0         73        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.50it/s]
#                    all        100       1085      0.732      0.699      0.701      0.197
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/199       3.9G    0.06082    0.06679          0         97        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.72it/s]
#                    all        100       1085      0.723      0.748      0.731      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/199       3.9G    0.05785    0.06519          0        105        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.62it/s]
#                    all        100       1085      0.722      0.735      0.726      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/199       3.9G    0.05952    0.06676          0         96        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.65it/s]
#                    all        100       1085      0.712      0.753      0.741      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/199       3.9G    0.05986    0.06205          0         71        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.66it/s]
#                    all        100       1085      0.671       0.76      0.707       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/199       3.9G     0.0587    0.06507          0         97        640: 100% 32/32 [00:06<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.72it/s]
#                    all        100       1085      0.696      0.724      0.701      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/199       3.9G    0.05919    0.06446          0         45        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.69it/s]
#                    all        100       1085      0.688      0.729      0.699        0.2
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/199       3.9G    0.05859    0.06502          0         75        640: 100% 32/32 [00:06<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.74it/s]
#                    all        100       1085        0.7      0.732      0.716       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/199       3.9G    0.05881    0.06495          0         74        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.74it/s]
#                    all        100       1085      0.754      0.729      0.744      0.218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/199       3.9G      0.055    0.06513          0         69        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.58it/s]
#                    all        100       1085      0.625      0.652      0.586      0.157
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/199       3.9G    0.05617    0.06473          0         44        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.75it/s]
#                    all        100       1085      0.743      0.752      0.757      0.215
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/199       3.9G    0.05829    0.06446          0         93        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.46it/s]
#                    all        100       1085      0.714      0.733      0.745      0.213
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/199       3.9G    0.05889    0.06605          0         93        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.82it/s]
#                    all        100       1085      0.667      0.687      0.662      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/199       3.9G    0.05474    0.06356          0         83        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.38it/s]
#                    all        100       1085       0.67      0.697      0.681      0.185
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/199       3.9G    0.05891    0.06287          0         48        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.67it/s]
#                    all        100       1085       0.71      0.764      0.741      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/199       3.9G    0.05798    0.06187          0         55        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.36it/s]
#                    all        100       1085      0.706      0.718      0.724      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/199       3.9G    0.05785    0.06441          0         58        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.67it/s]
#                    all        100       1085      0.732      0.719      0.741      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/199       3.9G    0.05621    0.06163          0         51        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.30it/s]
#                    all        100       1085      0.696      0.719      0.713      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/199       3.9G    0.05704    0.06419          0         87        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.77it/s]
#                    all        100       1085      0.649      0.708      0.654      0.181
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/199       3.9G     0.0571    0.06636          0         73        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.37it/s]
#                    all        100       1085      0.708      0.741      0.705      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/199       3.9G    0.05642    0.06198          0         73        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.78it/s]
#                    all        100       1085      0.717      0.745      0.723      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/199       3.9G    0.05739    0.06235          0         67        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.51it/s]
#                    all        100       1085      0.703      0.734      0.714       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/199       3.9G    0.05697    0.06571          0         89        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.65it/s]
#                    all        100       1085      0.629      0.666      0.623      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/199       3.9G    0.05725    0.06487          0         72        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.43it/s]
#                    all        100       1085      0.684      0.729      0.687      0.195
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/199       3.9G    0.05737    0.06469          0         92        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.77it/s]
#                    all        100       1085      0.687      0.773      0.726      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/199       3.9G    0.05621    0.06398          0         88        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.63it/s]
#                    all        100       1085      0.665      0.736      0.689      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/199       3.9G    0.05764    0.06239          0         86        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.67it/s]
#                    all        100       1085      0.727      0.738       0.72      0.215
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/199       3.9G    0.05713    0.06339          0         85        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.57it/s]
#                    all        100       1085      0.689      0.715      0.695      0.196
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/199       3.9G    0.05465    0.06398          0         68        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.71it/s]
#                    all        100       1085      0.691      0.767      0.705      0.204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/199       3.9G    0.05484    0.06289          0         99        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.72it/s]
#                    all        100       1085       0.72      0.766      0.751      0.215
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/199       3.9G     0.0576    0.06262          0         62        640: 100% 32/32 [00:06<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.77it/s]
#                    all        100       1085      0.707      0.772      0.746      0.216
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/199       3.9G    0.05566    0.06476          0        102        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.79it/s]
#                    all        100       1085      0.666      0.724      0.688      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/199       3.9G    0.05542    0.06337          0         52        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.69it/s]
#                    all        100       1085      0.689      0.741      0.709      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/199       3.9G    0.05681     0.0632          0         83        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.76it/s]
#                    all        100       1085      0.706      0.769      0.742      0.213
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/199       3.9G    0.05455     0.0645          0         50        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.53it/s]
#                    all        100       1085      0.686      0.757      0.729       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/199       3.9G    0.05529    0.06654          0         70        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.83it/s]
#                    all        100       1085      0.681      0.758       0.73      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/199       3.9G    0.05468    0.06387          0         76        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.21it/s]
#                    all        100       1085      0.732       0.72       0.73      0.214
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/199       3.9G    0.05309    0.06251          0         88        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.80it/s]
#                    all        100       1085      0.698      0.735      0.723      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/199       3.9G    0.05414    0.06246          0         85        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.46it/s]
#                    all        100       1085      0.713      0.743      0.734      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/199       3.9G    0.05428    0.06469          0         80        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.73it/s]
#                    all        100       1085      0.708      0.763      0.729      0.214
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/199       3.9G    0.05425    0.06363          0        109        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.56it/s]
#                    all        100       1085      0.707       0.75      0.712      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/199       3.9G    0.05592    0.06488          0         69        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        100       1085      0.688      0.728      0.695      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/199       3.9G    0.05557    0.06452          0         72        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.50it/s]
#                    all        100       1085       0.71      0.753      0.713      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/199       3.9G    0.05454    0.06261          0         61        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.76it/s]
#                    all        100       1085      0.692      0.766      0.727      0.215
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/199       3.9G    0.05433    0.06436          0        119        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.44it/s]
#                    all        100       1085      0.684      0.728        0.7      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/199       3.9G    0.05551    0.06403          0         47        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.82it/s]
#                    all        100       1085      0.677      0.741      0.703      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/199       3.9G    0.05642    0.06473          0         98        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.57it/s]
#                    all        100       1085      0.678      0.748       0.71      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/199       3.9G    0.05423      0.064          0         49        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.71it/s]
#                    all        100       1085      0.713      0.766      0.734      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/199       3.9G    0.05761    0.06344          0         93        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.65it/s]
#                    all        100       1085      0.679       0.77        0.7      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/199       3.9G    0.05579    0.06289          0         89        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.67it/s]
#                    all        100       1085      0.698       0.73      0.722      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/199       3.9G    0.05445     0.0631          0         71        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.63it/s]
#                    all        100       1085      0.688       0.74       0.71        0.2
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/199       3.9G    0.05363    0.06418          0        107        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.60it/s]
#                    all        100       1085        0.7      0.769      0.745       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/199       3.9G    0.05414    0.06426          0        102        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.85it/s]
#                    all        100       1085      0.691      0.773      0.714      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/199       3.9G    0.05387    0.06475          0         89        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.65it/s]
#                    all        100       1085      0.707      0.753      0.711      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/199       3.9G    0.05379    0.06159          0         80        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.76it/s]
#                    all        100       1085      0.721      0.783      0.761      0.222
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/199       3.9G    0.05393    0.06215          0         53        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.39it/s]
#                    all        100       1085      0.693      0.778      0.747      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/199       3.9G    0.05242    0.06326          0         43        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.71it/s]
#                    all        100       1085      0.733      0.773      0.748      0.217
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/199       3.9G    0.05341    0.06239          0         50        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.44it/s]
#                    all        100       1085      0.724      0.756      0.735      0.216
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/199       3.9G    0.05256    0.06025          0         37        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.89it/s]
#                    all        100       1085      0.694      0.739      0.719      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/199       3.9G    0.05197    0.06485          0        143        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.42it/s]
#                    all        100       1085       0.66      0.758      0.707      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/199       3.9G    0.05251    0.06084          0         76        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.74it/s]
#                    all        100       1085        0.7      0.782      0.749      0.217
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/199       3.9G    0.05335    0.06373          0         77        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.46it/s]
#                    all        100       1085      0.719      0.754      0.723      0.213
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/199       3.9G    0.05347    0.06118          0         62        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        100       1085      0.681      0.782       0.72      0.213
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/199       3.9G    0.05328    0.06245          0         68        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.40it/s]
#                    all        100       1085      0.684      0.757      0.712      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/199       3.9G    0.05258    0.06172          0         55        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.80it/s]
#                    all        100       1085      0.681      0.731      0.686      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/199       3.9G    0.05407    0.06275          0         63        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.46it/s]
#                    all        100       1085      0.681      0.747      0.702      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/199       3.9G    0.05444     0.0626          0         77        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.79it/s]
#                    all        100       1085      0.673      0.732      0.682      0.198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/199       3.9G     0.0528    0.06165          0         47        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.53it/s]
#                    all        100       1085      0.694      0.778      0.737      0.217
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/199       3.9G    0.05292      0.064          0         82        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        100       1085      0.693      0.772      0.732      0.216
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/199       3.9G    0.05296    0.06383          0         76        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.68it/s]
#                    all        100       1085      0.728      0.725      0.734      0.212
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/199       3.9G    0.05221    0.06335          0         58        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        100       1085        0.7      0.768      0.716      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/199       3.9G    0.05199    0.06171          0         61        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.71it/s]
#                    all        100       1085      0.676      0.763      0.721       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/199       3.9G    0.05196    0.06303          0         43        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.52it/s]
#                    all        100       1085      0.678      0.763      0.709        0.2
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/199       3.9G    0.05542    0.06271          0         69        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.74it/s]
#                    all        100       1085      0.703      0.771       0.73       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
# ...
#     162/199       3.9G    0.04804    0.06086          0         49        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.79it/s]
#                    all        100       1085      0.682      0.749      0.681      0.196
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     163/199       3.9G    0.04652    0.05748          0         53        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.53it/s]
#                    all        100       1085      0.708      0.752      0.699      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     164/199       3.9G    0.04704    0.05899          0        107        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.87it/s]
#                    all        100       1085      0.725      0.755      0.706      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     165/199       3.9G    0.04653    0.05961          0         95        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.60it/s]
#                    all        100       1085      0.729      0.763      0.716      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     166/199       3.9G    0.04624    0.05931          0         67        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.78it/s]
#                    all        100       1085      0.704       0.77      0.702      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     167/199       3.9G    0.04557    0.05849          0        113        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.67it/s]
#                    all        100       1085      0.712      0.763      0.706      0.208
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     168/199       3.9G    0.04592    0.06083          0        141        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.83it/s]
#                    all        100       1085      0.697       0.75      0.697      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     169/199       3.9G    0.04622    0.05928          0        108        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.65it/s]
#                    all        100       1085      0.699      0.767      0.701      0.204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     170/199       3.9G    0.04769    0.05689          0        114        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.72it/s]
#                    all        100       1085       0.72      0.754      0.705      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     171/199       3.9G    0.04569    0.05817          0         90        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.76it/s]
#                    all        100       1085      0.715      0.762      0.704      0.209
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     172/199       3.9G    0.04609    0.05803          0         72        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.70it/s]
#                    all        100       1085       0.71      0.757      0.696      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     173/199       3.9G    0.04653    0.05757          0         89        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.82it/s]
#                    all        100       1085      0.709      0.772      0.706      0.211
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     174/199       3.9G    0.04706    0.05965          0        109        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.68it/s]
#                    all        100       1085      0.698      0.765      0.693      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     175/199       3.9G    0.04544    0.05669          0         67        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.82it/s]
#                    all        100       1085      0.702      0.752      0.701      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     176/199       3.9G    0.04589    0.05949          0         65        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.63it/s]
#                    all        100       1085        0.7       0.76      0.694      0.204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     177/199       3.9G    0.04722    0.05734          0         37        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.78it/s]
#                    all        100       1085      0.714      0.748      0.693      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     178/199       3.9G    0.04723    0.05962          0         90        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.51it/s]
#                    all        100       1085      0.703      0.761      0.702      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     179/199       3.9G    0.04792    0.05819          0         75        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.87it/s]
#                    all        100       1085      0.689      0.766      0.703      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     180/199       3.9G    0.04536    0.05782          0         59        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.47it/s]
#                    all        100       1085      0.669      0.755      0.687      0.199
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     181/199       3.9G    0.04632    0.05871          0         71        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.84it/s]
#                    all        100       1085      0.694      0.764      0.704      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     182/199       3.9G    0.04561    0.05886          0         85        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.56it/s]
#                    all        100       1085       0.69       0.76      0.699      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     183/199       3.9G    0.04434    0.05715          0         65        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.80it/s]
#                    all        100       1085      0.693       0.77      0.708      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     184/199       3.9G    0.04608    0.05842          0         98        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.47it/s]
#                    all        100       1085       0.69      0.758      0.687      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     185/199       3.9G    0.04545    0.05813          0         54        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.80it/s]
#                    all        100       1085      0.686      0.751      0.696      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     186/199       3.9G    0.04443    0.05915          0         95        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.57it/s]
#                    all        100       1085      0.682      0.766      0.692      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     187/199       3.9G    0.04706    0.05634          0         37        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.83it/s]
#                    all        100       1085      0.687      0.772      0.701      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     188/199       3.9G    0.04598    0.05906          0         72        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.54it/s]
#                    all        100       1085      0.688      0.769        0.7      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     189/199       3.9G     0.0454    0.05854          0        100        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.81it/s]
#                    all        100       1085      0.672      0.764       0.68      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     190/199       3.9G    0.04589    0.05847          0         88        640: 100% 32/32 [00:06<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.63it/s]
#                    all        100       1085      0.682      0.772      0.692      0.202
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     191/199       3.9G     0.0441    0.05806          0         61        640: 100% 32/32 [00:06<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.86it/s]
#                    all        100       1085      0.694      0.766      0.704      0.206
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     192/199       3.9G    0.04478     0.0576          0         87        640: 100% 32/32 [00:06<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.51it/s]
#                    all        100       1085        0.7      0.762      0.706      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     193/199       3.9G    0.04603    0.05905          0         89        640: 100% 32/32 [00:06<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.85it/s]
#                    all        100       1085       0.69      0.766      0.707       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     194/199       3.9G    0.04486    0.05846          0         52        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.63it/s]
#                    all        100       1085        0.7      0.759      0.698      0.204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     195/199       3.9G    0.04554     0.0579          0         77        640: 100% 32/32 [00:06<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.76it/s]
#                    all        100       1085      0.707      0.755      0.699      0.207
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     196/199       3.9G    0.04551    0.05784          0        111        640: 100% 32/32 [00:06<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.68it/s]
#                    all        100       1085      0.705      0.747      0.693      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     197/199       3.9G    0.04456    0.05862          0         89        640: 100% 32/32 [00:06<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.83it/s]
#                    all        100       1085      0.693      0.753      0.692      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     198/199       3.9G    0.04386     0.0561          0        102        640: 100% 32/32 [00:06<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.87it/s]
#                    all        100       1085      0.691      0.765      0.697      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     199/199       3.9G     0.0453    0.05711          0         82        640: 100% 32/32 [00:06<00:00,  4.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:01<00:00,  3.67it/s]
#                    all        100       1085      0.706      0.744      0.699      0.205
#
# 200 epochs completed in 0.472 hours.
# Optimizer stripped from runs/train/meteor/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/meteor/weights/best.pt, 14.4MB
#
# Validating runs/train/meteor/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:02<00:00,  1.53it/s]
#                    all        100       1085      0.738       0.77      0.764      0.226
# Results saved to runs/train/meteor

# %% [markdown]
# ### Creating a directory to save the model

# %%
#!mkdir -p /content/drive/MyDrive/cnnyolov5_meteor

# %%
save_path = '/content/drive/MyDrive/cnnyolov5_meteor'

# %%
# !cp /content/yolov5/runs/train/meteor3/weights/best.pt {save_path}/best.pt
# !cp /content/yolov5/runs/train/meteor3/weights/last.pt {save_path}/last.pt

# %%
# !cp -r /content/yolov5/runs/train/meteor3 {save_path}/traindata

# %% [markdown]
# ## Detecting our model on unseen data.

# %%
# Load the model
# !python detect.py --weights /content/yolov5/runs/train/meteor/weights/best.pt --img 640 --conf 0.4 --source /content/drive/MyDrive/class_multi/images/val/RAD_BEDOUR_20240619_0035_BELEUV_SYS001.png
# change the --source 'image.png' as per your test image.
# Out:
# detect: weights=['/content/yolov5/runs/train/meteor/weights/best.pt'], source=/content/drive/MyDrive/class_multi/images/val/RAD_BEDOUR_20240619_0035_BELEUV_SYS001.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.12 torch-2.3.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/class_multi/images/val/RAD_BEDOUR_20240619_0035_BELEUV_SYS001.png: 416x640 10 meteors, 77.2ms
# Speed: 0.8ms pre-process, 77.2ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# Load the model
# !python detect.py --weights /content/yolov5/runs/train/meteor/weights/best.pt --img 640 --conf 0.4 --source /content/drive/MyDrive/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png
# Out:
# detect: weights=['/content/yolov5/runs/train/meteor/weights/best.pt'], source=/content/drive/MyDrive/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.12 torch-2.3.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png: 416x640 10 meteors, 78.0ms
# Speed: 0.8ms pre-process, 78.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# !cp /content/yolov5/runs/detect/exp2/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png {save_path}/output
# !cp /content/yolov5/runs/detect/exp/RAD_BEDOUR_20240619_0035_BELEUV_SYS001.png {save_path}/output1

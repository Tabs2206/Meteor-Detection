# %% [markdown]
# <a href="https://colab.research.google.com/github/Tabs2206/Meteor-Detection/blob/main/modelyolov5/Meteor_Classification_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.7/201.2 GB disk)

# %% [markdown]
# # Include a YAML
#
# For training the model in our own classifiation we need to add a new YAML file containing the below details.
#
#
#
# ```
# train: /content/drive/MyDrive/class_meteor/images/train # path to training images
# val: /content/drive/MyDrive/class_meteor/images/val  # path to validation images
# test: /content/drive/MyDrive/class_meteor/images/test  # path to test images (optional)
#
#
# nc: 1  # number of classes
# names: ['meteor']  # class names
# ```
#
# This will contain the path of the labelled data set for training, validation and test and the class i.e, meteor in our case.
#
# Drag and drop the file in the file path "/content/yolov5/data"
#
# In the below code we have utilse is under --data to get the training data for training our(train.py)

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 100 --data /content/yolov5/data/coco128_meteor.yaml --weights yolov5s.pt --name meteor_yolov5
# Out:
# 2024-08-18 11:02:37.769241: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-18 11:02:38.015094: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-18 11:02:38.078028: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/meteor_yolov5/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png
# Out:
# detect: weights=['/content/yolov5/runs/train/meteor_yolov5/weights/best.pt'], source=/content/drive/MyDrive/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/drive/MyDrive/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png: 416x640 12 meteors, 77.0ms
# Speed: 0.8ms pre-process, 77.0ms inference, 852.2ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# !mkdir -p /content/drive/MyDrive/meteoryolov5

# %%
save_path = '/content/drive/MyDrive/meteoryolov5'

# %%
# !cp /content/yolov5/runs/train/meteor_yolov5/weights/best.pt {save_path}/best.pt
# !cp /content/yolov5/runs/train/meteor_yolov5/weights/last.pt {save_path}/last.pt

# %%
# !cp -r /content/yolov5/runs/train/meteor_yolov5 {save_path}/traindata

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/meteor_yolov5/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/class_multi/images/train/RAD_BEDOUR_20240605_0020_BEHUMA_SYS003.png
# Out:
# detect: weights=['/content/yolov5/runs/train/meteor_yolov5/weights/best.pt'], source=/content/drive/MyDrive/class_multi/images/train/RAD_BEDOUR_20240605_0020_BEHUMA_SYS003.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-353-g5eca7b9c Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/class_multi/images/train/RAD_BEDOUR_20240605_0020_BEHUMA_SYS003.png: 416x640 10 meteors, 51.6ms
# ...

# %%
# !cp /content/yolov5/runs/detect/exp/RAD_BEDOUR_20240610_0200_BEHUMA_SYS002.png {save_path}/output
# !cp /content/yolov5/runs/detect/exp2/RAD_BEDOUR_20240605_0020_BEHUMA_SYS003.png {save_path}/output1
